# %% [markdown]
# **Making of a well data to feed in Model**

# %%
import pandas as pd

# %%
df=pd.read_csv('moru_reviews_cleaned_static.csv')
print(df.head())
# Out:
#                                          review_text  rating  \
# 0  Useless app. Only asked to upload the photo ho...       1
# 1                                               good       5
# 2  Bank account link garna ko lagi Bank haru ali ...       3
# 3  Top-up ma Cashback KO lagi use garna saknu hunxa.       3
# 4                                           thik tha       3
#
#                   date                                       clean_review  \
# 0  2025-12-21 03:15:21  useless app only asked to upload the photo hol...
# 1  2025-12-14 14:46:01                                               good
# 2  2025-12-03 09:26:39  bank account link garna ko lagi bank haru ali ...
# 3  2025-12-02 11:28:14    topup ma cashback ko lagi use garna saknu hunxa
# 4  2025-11-17 14:59:22                                           thik tha
#
#   baseline_sentiment
# 0                Bad
# 1               Good
# 2            Neutral
# 3            Neutral
# 4            Neutral

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

checkpoint = "santoshdahal/setu"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)

def translate_to_en(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True)
    output = model.generate(**inputs, max_length=256)
    return tokenizer.decode(output[0], skip_special_tokens=True)



df = pd.read_csv('moru_reviews_cleaned_static.csv')
df['translated_review'] = df['clean_review'].apply(translate_to_en)
df.to_csv('moru_reviews_translated.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[9], line 3
#       1 from google.cloud import translate_v2 as translate
# ----> 3 translate_client = translate.Client()
#       5 def translate_to_en(text):
#       6     try:
#
# File ~/projects/review-extract/venv/lib/python3.12/site-packages/google/cloud/translate_v2/client.py:79, in Client.__init__(self, target_language, credentials, _http, client_info, client_options)
#      70 def __init__(
#      71     self,
#      72     target_language=ENGLISH_ISO_639,
#    (...)     76     client_options=None,
#      77 ):
#      78     self.target_language = target_language
# ---> 79     super(Client, self).__init__(credentials=credentials, _http=_http)
#      81     kw_args = {"client_info": client_info}
#      82     if client_options:
#
# ...
